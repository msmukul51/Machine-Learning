# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
from sklearn import metrics

# %%
import pandas as pd

df =pd.read_csv("/content/drive/MyDrive/Colab Notebooks/CarPrice_Assignment.csv")
df.head(5)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
df.head().T
# Out:
#                                    0  ...           4
# car_ID                             1  ...           5
# symboling                          3  ...           2
# CarName           alfa-romero giulia  ...  audi 100ls
# fueltype                         gas  ...         gas
# aspiration                       std  ...         std
# doornumber                       two  ...        four
# carbody                  convertible  ...       sedan
# drivewheel                       rwd  ...         4wd
# enginelocation                 front  ...       front
# wheelbase                       88.6  ...        99.4
# carlength                      168.8  ...       176.6
# carwidth                        64.1  ...        66.4
# carheight                       48.8  ...        54.3
# curbweight                      2548  ...        2824
# enginetype                      dohc  ...         ohc
# cylindernumber                  four  ...        five
# enginesize                       130  ...         136
# fuelsystem                      mpfi  ...        mpfi
# boreratio                       3.47  ...        3.19
# stroke                          2.68  ...         3.4
# compressionratio                 9.0  ...         8.0
# horsepower                       111  ...         115
# peakrpm                         5000  ...        5500
# citympg                           21  ...          18
# highwaympg                        27  ...          22
# price                        13495.0  ...     17450.0
#
# [26 rows x 5 columns]

# %%
df.drop('car_ID', axis = 1, inplace = True)

# %%
df.shape
# Out:
# (205, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
#  16  fuelsystem        205 non-null    object
#  17  boreratio         205 non-null    float64
#  18  stroke            205 non-null    float64
#  19  compressionratio  205 non-null    float64
#  20  horsepower        205 non-null    int64
#  21  peakrpm           205 non-null    int64
#  22  citympg           205 non-null    int64
#  23  highwaympg        205 non-null    int64
#  24  price             205 non-null    float64
# dtypes: float64(8), int64(7), object(10)
# memory usage: 40.2+ KB

# %%
df.isna().sum()
# Out:
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df['CarName'].value_counts()
# Out:
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: CarName, Length: 147, dtype: int64

# %%
df['CarName'].str.split(' ').str.get(0).nunique()
# Out:
# 28

# %%
df['company']=df['CarName'].str.split(' ').str.get(0)

# %%
df['company'].value_counts()
# Out:
# toyota         31
# nissan         17
# mazda          15
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# volkswagen      9
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# isuzu           4
# porsche         4
# alfa-romero     3
# chevrolet       3
# jaguar          3
# vw              2
# maxda           2
# renault         2
# toyouta         1
# vokswagen       1
# Nissan          1
# mercury         1
# porcshce        1
# Name: company, dtype: int64

# %%
df.loc[df['company']=='vw','company']='volkswagen'
df.loc[df['company']=='porcshce','company']='porsche'
df.loc[df['company']=='nissan','company']='Nissan'
df.loc[df['company']=='maxda','company']='mazda'
df.loc[df['company']=='toyouta','company']='toyota'
df.loc[df['company']=='vokswagen','company']='volkswagen'

# %%
df['company'].nunique()
# Out:
# 22

# %%
df['company'].value_counts()
# Out:
# toyota         32
# Nissan         18
# mazda          17
# mitsubishi     13
# honda          13
# volkswagen     12
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# porsche         5
# isuzu           4
# jaguar          3
# chevrolet       3
# alfa-romero     3
# renault         2
# mercury         1
# Name: company, dtype: int64

# %%
df.drop('CarName',axis=1,inplace=True)

# %%
df['company'].value_counts(normalize=True)*100
# Out:
# toyota         15.609756
# Nissan          8.780488
# mazda           8.292683
# mitsubishi      6.341463
# honda           6.341463
# volkswagen      5.853659
# subaru          5.853659
# peugeot         5.365854
# volvo           5.365854
# dodge           4.390244
# buick           3.902439
# bmw             3.902439
# audi            3.414634
# plymouth        3.414634
# saab            2.926829
# porsche         2.439024
# isuzu           1.951220
# jaguar          1.463415
# chevrolet       1.463415
# alfa-romero     1.463415
# renault         0.975610
# mercury         0.487805
# Name: company, dtype: float64

# %%
def group(x):
  if 'renault' in x:
    return 'other'
  elif 'mercury'in x:
    return 'other'
  else:
    return x

# %%
df['company']=df['company'].apply(lambda x:group(x))

# %%
df['company'].value_counts(normalize=True)*100
# Out:
# toyota         15.609756
# Nissan          8.780488
# mazda           8.292683
# honda           6.341463
# mitsubishi      6.341463
# subaru          5.853659
# volkswagen      5.853659
# peugeot         5.365854
# volvo           5.365854
# dodge           4.390244
# buick           3.902439
# bmw             3.902439
# audi            3.414634
# plymouth        3.414634
# saab            2.926829
# porsche         2.439024
# isuzu           1.951220
# alfa-romero     1.463415
# jaguar          1.463415
# chevrolet       1.463415
# other           1.463415
# Name: company, dtype: float64

# %%
df.dtypes
# Out:
# symboling             int64
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# company              object
# dtype: object

# %%
cat_col = [df.dtypes.index[i] for i in range (len(df.dtypes)) if df.dtypes[i] == 'object']
cat_col
# Out:
# ['fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem',
#  'company']

# %%
num_col = [i for i in df.columns if i  not in cat_col ]
num_col
# Out:
# ['symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
for i in cat_col:
  if i!='company':
    print('\n',df[i].value_counts(normalize=True)*100)
  else:
    pass
# Out:
#  gas       90.243902
# diesel     9.756098
# Name: fueltype, dtype: float64
#
#  std      81.95122
# turbo    18.04878
# Name: aspiration, dtype: float64
#
#  four    56.097561
# two     43.902439
# Name: doornumber, dtype: float64
#
#  sedan          46.829268
# hatchback      34.146341
# wagon          12.195122
# hardtop         3.902439
# convertible     2.926829
# Name: carbody, dtype: float64
#
#  fwd    58.536585
# rwd    37.073171
# 4wd     4.390244
# Name: drivewheel, dtype: float64
#
#  front    98.536585
# rear      1.463415
# Name: enginelocation, dtype: float64
#
#  ohc      72.195122
# ohcf      7.317073
# ohcv      6.341463
# dohc      5.853659
# l         5.853659
# rotor     1.951220
# dohcv     0.487805
# Name: enginetype, dtype: float64
#
#  four      77.560976
# six       11.707317
# five       5.365854
# eight      2.439024
# two        1.951220
# three      0.487805
# twelve     0.487805
# Name: cylindernumber, dtype: float64
#
#  mpfi    45.853659
# 2bbl    32.195122
# idi      9.756098
# 1bbl     5.365854
# spdi     4.390244
# 4bbl     1.463415
# mfi      0.487805
# spfi     0.487805
# Name: fuelsystem, dtype: float64

# %% [markdown]
# ## **Univariate** **Analysis**

# %%
for i in cat_col:
  if i!='company':
    fig,ax=plt.subplots()
    plt.title(i)
    sns.barplot(x=df[i].value_counts().index,y=(df[i].value_counts(normalize=True)*100).values)

# %%
for col in num_col:
  plt.subplot(1,2,1)
  sns.histplot(df[col],kde=True)
  plt.subplot(1,2,2)
  sns.boxplot(df[col])
  plt.tight_layout()
  plt.show()

# %%
Checking for outliers in compression ratio

# %%
df[df['compressionratio']>15]
# Out:
#      symboling fueltype aspiration  ... citympg    price     company
# 63           0   diesel        std  ...      36  10795.0       mazda
# 66           0   diesel        std  ...      31  18344.0       mazda
# 67          -1   diesel      turbo  ...      22  25552.0       buick
# 68          -1   diesel      turbo  ...      22  28248.0       buick
# 69           0   diesel      turbo  ...      22  28176.0       buick
# 70          -1   diesel      turbo  ...      22  31600.0       buick
# 90           1   diesel        std  ...      45   7099.0      Nissan
# 108          0   diesel      turbo  ...      28  13200.0     peugeot
# 110          0   diesel      turbo  ...      25  13860.0     peugeot
# 112          0   diesel      turbo  ...      28  16900.0     peugeot
# 114          0   diesel      turbo  ...      25  17075.0     peugeot
# 116          0   diesel      turbo  ...      28  17950.0     peugeot
# 158          0   diesel        std  ...      34   7898.0      toyota
# 159          0   diesel        std  ...      38   7788.0      toyota
# 174         -1   diesel      turbo  ...      30  10698.0      toyota
# 182          2   diesel        std  ...      37   7775.0  volkswagen
# 184          2   diesel        std  ...      37   7995.0  volkswagen
# 187          2   diesel      turbo  ...      37   9495.0  volkswagen
# 192          0   diesel      turbo  ...      33  13845.0  volkswagen
# 203         -1   diesel      turbo  ...      26  22470.0       volvo
#
# [20 rows x 23 columns]

# %%
sns.boxplot(x='fueltype',y='compressionratio',data=df);

# %% [markdown]
# Checking for outliers in enginesize feature

# %%
df['enginesize'].quantile([0.95,0.96,0.97,0.98,0.99,1])
# Out:
# 0.95    201.20
# 0.96    209.00
# 0.97    231.00
# 0.98    256.08
# 0.99    302.16
# 1.00    326.00
# Name: enginesize, dtype: float64

# %%
df[df['enginesize']>250]
# Out:
#     symboling fueltype aspiration doornumber  ... peakrpm citympg    price  company
# 47          0      gas        std       four  ...    4750      15  32250.0   jaguar
# 48          0      gas        std       four  ...    4750      15  35550.0   jaguar
# 49          0      gas        std        two  ...    5000      13  36000.0   jaguar
# 73          0      gas        std       four  ...    4500      14  40960.0    buick
# 74          1      gas        std        two  ...    4500      14  45400.0    buick
#
# [5 rows x 23 columns]

# %% [markdown]
# checking for outliers in price feature

# %%
df['price'].quantile([0.95,0.96,0.97,0.98,0.99])
# Out:
# 0.95    32472.40
# 0.96    34159.04
# 0.97    35490.72
# 0.98    36809.60
# 0.99    40802.72
# Name: price, dtype: float64

# %%
df[df['price']>30000]
# Out:
#      symboling fueltype aspiration  ... citympg    price  company
# 15           0      gas        std  ...      16  30760.0      bmw
# 16           0      gas        std  ...      16  41315.0      bmw
# 17           0      gas        std  ...      15  36880.0      bmw
# 47           0      gas        std  ...      15  32250.0   jaguar
# 48           0      gas        std  ...      15  35550.0   jaguar
# 49           0      gas        std  ...      13  36000.0   jaguar
# 70          -1   diesel      turbo  ...      22  31600.0    buick
# 71          -1      gas        std  ...      16  34184.0    buick
# 72           3      gas        std  ...      16  35056.0    buick
# 73           0      gas        std  ...      14  40960.0    buick
# 74           1      gas        std  ...      14  45400.0    buick
# 126          3      gas        std  ...      17  32528.0  porsche
# 127          3      gas        std  ...      17  34028.0  porsche
# 128          3      gas        std  ...      17  37028.0  porsche
# 129          1      gas        std  ...      17  31400.5  porsche
#
# [15 rows x 23 columns]

# %% [markdown]
# ### **Bivariate** **Analysis**

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='company',y='price',data=df);
plt.xticks(rotation='vertical');

# %%
sns.jointplot(x='enginesize',y='price',data=df,kind='reg');

# %%
np.round(df['enginesize'].corr(df['price']),2)
# Out:
# 0.87

# %%
sns.boxplot(x='enginetype',y='price',data=df);

# %%
df['drivewheel'].value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
sns.boxplot(x='drivewheel',y='price',data=df);

# %% [markdown]
# ## **MULTIVARAITE** **ANALYSIS**

# %%
sns.scatterplot(x='horsepower',y='price',hue='fueltype',data=df);

# %%
sns.scatterplot(x='peakrpm',y='price',hue='cylindernumber',data=df);

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cmap='BuPu',annot=True);

# %%
df.drop('highwaympg',axis=1,inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cmap='rocket',annot=True);

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x=corr.index,y=corr.values,color='black');
plt.xticks(rotation='vertical');

# %%
df.drop('wheelbase',axis=1,inplace=True)

# %%
corr=df.corr()['price'].sort_values(ascending=False)[1:]
corr
# Out:
# enginesize          0.874145
# curbweight          0.835305
# horsepower          0.808139
# carwidth            0.759325
# carlength           0.682920
# boreratio           0.553173
# carheight           0.119336
# stroke              0.079443
# compressionratio    0.067984
# symboling          -0.079978
# peakrpm            -0.085267
# citympg            -0.685751
# Name: price, dtype: float64

# %%
catdf=df[cat_col]

# %%
dummies=pd.get_dummies(catdf,drop_first=True)

# %%
df1=df.drop(list(catdf.columns),axis=1)

# %%
df2=pd.concat([df1,dummies],axis=1)

# %%
df2.columns
# Out:
# Index(['symboling', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'price', 'fueltype_gas', 'aspiration_turbo',
#        'doornumber_two', 'carbody_hardtop', 'carbody_hatchback',
#        'carbody_sedan', 'carbody_wagon', 'drivewheel_fwd', 'drivewheel_rwd',
#        'enginelocation_rear', 'enginetype_dohcv', 'enginetype_l',
#        'enginetype_ohc', 'enginetype_ohcf', 'enginetype_ohcv',
#        'enginetype_rotor', 'cylindernumber_five', 'cylindernumber_four',
#        'cylindernumber_six', 'cylindernumber_three', 'cylindernumber_twelve',
#        'cylindernumber_two', 'fuelsystem_2bbl', 'fuelsystem_4bbl',
#        'fuelsystem_idi', 'fuelsystem_mfi', 'fuelsystem_mpfi',
#        'fuelsystem_spdi', 'fuelsystem_spfi', 'company_alfa-romero',
#        'company_audi', 'company_bmw', 'company_buick', 'company_chevrolet',
#        'company_dodge', 'company_honda', 'company_isuzu', 'company_jaguar',
#        'company_mazda', 'company_mitsubishi', 'company_other',
#        'company_peugeot', 'company_plymouth', 'company_porsche',
#        'company_saab', 'company_subaru', 'company_toyota',
#        'company_volkswagen', 'company_volvo'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X=df2.drop('price',axis=1)
y=df2['price']

# %%
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size=0.25,random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()

# %%
from sklearn import metrics
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
param={
    'criterion':['squared_error', 'absolute_error', 'poisson'],
    'max_depth':range(2,5),
    'max_features':['auto', 'sqrt', 'log2'],

}

# %%
from sklearn.model_selection import GridSearchCV
search=GridSearchCV(rf,param,n_jobs=-1,cv=5)
search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_depth': range(2, 5),
#                          'max_features': ['auto', 'sqrt', 'log2']})

# %%
search.best_params_
# Out:
# {'criterion': 'absolute_error', 'max_depth': 4, 'max_features': 'auto'}

# %%
y_pred_gridtrain=search.predict(X_train)

# %%
y_pred_gridtest=search.predict(X_test)

# %%
n,p=X_train.shape[0],X_train.shape[1]

# %%
r2tr=metrics.r2_score(y_train,y_pred_gridtrain)
print(f'R2Score on Training data is {r2tr}')
num=(1-r2tr)*(n-1)
den=n-p-1
ar2tr=1-(num/den)
print(f'Adjusted R2 score for training data is {ar2tr}')
# Out:
# R2Score on Training data is 0.956812518725547
# Adjusted R2 score for training data is 0.9278626686404741

# %%
r2te=metrics.r2_score(y_test,y_pred_gridtest)
print(f'R2score on Testing data is {r2te}')
num=(1-r2te)*(n-1)
den=n-p-1
ar2te=1-(num/den)

print(f'Adjusted R2 score for testing data is {ar2te}')
# Out:
# R2score on Testing data is 0.9281670874542601
# Adjusted R2 score for testing data is 0.8800153548686543
